# %%
# List

a = [1, 2, 3]
print(a + [4, 5])  # Output: List +List [1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# numpy 陣列運算
import numpy as np

b = np.array([1, 2, 3])
print(b + np.array([4, 5, 6]))  # Output: 陣列相對運算 [5 7 9]
# Out:
# [5 7 9]
