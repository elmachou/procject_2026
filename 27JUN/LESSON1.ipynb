# %%
# List

a = [1, 2, 3]
print(a + [4, 5])  # Output: List +List [1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# numpy array
import numpy as np

b = np.array([1, 2, 3])
print(b + np.array([4, 5, 6]))  # Output: 陣列運算 [5 7 9]
# Out:
# [5 7 9]

# %%
arr1 = np.array([6, 7.5, 8, 0, 1])
print(type(arr1))
# Out:
# <class 'numpy.ndarray'>

# %%
arr2 = arr1 * 5
arr2
# Out:
# array([30. , 37.5, 40. ,  0. ,  5. ])

# %%
arr3 = arr1 / 10
arr3
# Out:
# array([0.6 , 0.75, 0.8 , 0.  , 0.1 ])

# %%
# numpy arrange
np.arange(5) 
np.arange(2, 6)
np.arange(1, 10, 2)
# Out:
# array([1, 3, 5, 7, 9])

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

t = np.arange(0, 2.5, 0.1)
print(len(t)) #25
t1 = t * math.pi #math裡pi的函數
y1 = np.sin(t1)
print(len(y1)) #25
y2 = np.cos(t1)
print(len(y2)) #25

fig = plt.figure()
axes = fig.add_subplot(1, 1, 1) #1 row, 1 column, 1st subplot
axes.plot(t, y1)
axes.plot(t, y2)
plt.show()
# Out:
# 25
# 25
# 25

# %%
import numpy as np
import matplotlib.pyplot as plt

t = np.arange(0, 5, 0.1)
y1 = np.sin(t * np.pi) #np裡也有pi的函數
y2 = np.cos(t * np.pi) 

figure = plt.figure()
ax1 = figure.add_subplot(2, 1, 1) #2 rows, 1 column, 1st subplot
ax1.plot(t, y1, linestyle="--", color="red") #-- dashed line
ax2 = figure.add_subplot(2, 1, 2) #2 rows, 1 column, 2nd subplot
ax2.plot(t, y2, linestyle="-.",color="blue") #-. dash-dot line
plt.show()

# %%
# 步驟 1:匯入 numpy,並取別名 np
import numpy as np

# 步驟 2:匯入 matplotlib.pyplot,並取別名 plt
import matplotlib.pyplot as plt

# 步驟 3:用 np.arange() 產生 0 到 4(不含 4)、間隔 0.2 的陣列,存入 x
x = np.arange(0, 4, 0.2)

# 步驟 4:計算 y1 = cos(pi * x)(用 np.cos 與 np.pi)
y1 = np.cos(x * np.pi)

# 步驟 5:計算 y2 = cos(2 * pi * x)
y2 = np.cos(2 * x * np.pi)

# 步驟 6:用 subplot 把版面切成 1 列 2 欄,選第 1 格(左圖)
figure = plt.figure()
ax1 = figure.add_subplot(1, 2, 1)

# 步驟 7:畫出 x 與 y1,使用綠色實線
ax1.plot(x, y1, color="green", linestyle="-")

# 步驟 8:用 subplot 選第 2 格(右圖)
ax2 = figure.add_subplot(1, 2, 2)

# 步驟 9:畫出 x 與 y2,使用洋紅色點線
ax2.plot(x, y2, color="magenta", linestyle=":")

# 步驟 10:顯示圖形
plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['Nokia', 'Samsung', 'Apple', 'Lumia']
values = [20, 30, 45, 10]
colors = ['yellow', 'green', 'red', 'blue']

figure = plt.figure()
axes = figure.add_subplot() # default 1 row, 1 column, 1st subplot (1, 1, 1)

# Pie 圓餅圖
axes.pie(values,
         labels=labels,
         colors=colors,
         explode=[0.3, 0, 0, 0], #跳出第一個區塊Nokia
         shadow=True,
         autopct="%2.1f%%", #整數位數2位, 小數點後 1 位數字百分比
         startangle=180)
plt.show()

# %%
# 步驟 1:匯入 matplotlib.pyplot,取別名為 plt
import matplotlib.pyplot as plt

# 設定中文字型為微軟正黑體,並設定負號正常顯示
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft JhengHei']  # 或 SimSun、微軟正黑體
plt.rcParams['axes.unicode_minus'] = False

# 步驟 2:建立飲料名稱的串列(奶茶、紅茶、綠茶、咖啡)
drinks = ['奶茶', '紅茶', '綠茶', '咖啡']

from matplotlib.font_manager import FontProperties
font = FontProperties(fname=r"c:\windows\fonts\simsun.ttc", size=14)

# 步驟 3:建立各飲料銷售杯數的串列(50、25、35、40)
sales = [50, 25, 35, 40]

# 步驟 4:建立四種顏色的串列
colors = ['yellow', 'green', 'red', 'blue']

# 步驟 5:建立 explode 串列,讓奶茶那一塊突出 0.2,其餘為 0
explode = [0.2, 0, 0, 0]

# 步驟 6:建立 figure
figure = plt.figure()

# 步驟 7:用 add_subplot() 建立 axes
axes = figure.add_subplot()

# 步驟 8:呼叫 axes.pie(),傳入杯數,並設定 labels、colors、explode、
#         startangle=90、shadow=True、autopct='%1.1f%%'
axes.pie(sales,
         labels=drinks,
         colors=colors,
         explode=explode,
         startangle=90,
         shadow=True,
         autopct="%1.1f%%") #整數位數1位, 小數點後 1 位數字百分比

# 步驟 9:用 plt.show() 顯示圖表
plt.show()

# %% [markdown]
# 延伸挑戰題
# 題目
# 讓使用者用 input() 輸入四種飲料各自的銷售杯數(原本固定的數字改成由鍵盤輸入),程式再依輸入的資料畫出圓餅圖。並自動讓「杯數最多」的那一塊突出,而不是固定突出奶茶。
#
# 提示:
# input() 讀進來是文字,要怎麼轉成數字才能放進 values?
# 如何找出串列中最大值的位置?(可查 max() 與 index())
# explode 串列要怎麼依「最大值位置」動態產生?
