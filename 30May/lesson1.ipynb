# %%
# List
# 可以修改的有序集合

scores = ["Student1", 90, 80, 70, 60, 50]
print(scores)
print(scores[0])  # list的索引從0開始 print第一筆資料
print(scores[1])  # print第二筆資料
print(scores[2])  # print第三筆資料 
print(scores[3])  # print第四筆資料
print(scores[4])  # print第五筆資料
print(scores[5])  # print第六筆資料
print(scores[-1])  # print最後一筆資料

# 修改list中的資料
scores[1] = 95  # 修改第二筆資料為95
print(scores)  # print修改後的list

for i in scores:
    print(i)  # print每筆資料
# Out:
# ['Student1', 90, 80, 70, 60, 50]
# Student1
# 90
# 80
# 70
# 60
# 50
# 50
# ['Student1', 95, 80, 70, 60, 50]
# Student1
# 95
# 80
# 70
# 60
# 50

# %%
# Tuple
# tuple建立後,不可以修改內容,read-only ordered collection

scores = ("Student1", 95, 85, 75, 65, 55)
print(scores)
print(scores[0])  # tuple的索引從0開始 print第一筆資料
print(scores[1])  # print第二筆資料
print(scores[2])  # print第三筆資料 
print(scores[3])  # print第四筆資料
print(scores[4])  # print第五筆資料
print(scores[5])  # print第六筆資料
print(scores[-1])  # print最後一筆資料

### 修改tuple中的資料
### scores[1] = 95  # 修改第二筆資料為95 (這會導致錯誤，因為tuple是不可修改的)

for j in scores:
    print(j)  # print每筆資料
# Out:
# ('Student1', 95, 85, 75, 65, 55)
# Student1
# 95
# 85
# 75
# 65
# 55
# 55
# Student1
# 95
# 85
# 75
# 65
# 55

# %%
# Dictionary
# dictionary是無序的key-value pair collection, key必須是唯一的, value可以是任何資料類型, dictionary是可修改的

Student1 = {
  "name": "EC", 
  "chinese": 90,
  "english": 80,
  "math": 85,
  "history": 70,
  "discovery": 95}

print(Student1)
print(Student1["name"])
print(Student1["chinese"])

for key in Student1:
    print(key) # print整個dictionary
    
for key in Student1:
    print(Student1[key])  # print每筆資料
# Out:
# {'name': 'EC', 'chinese': 90, 'english': 80, 'math': 85, 'history': 70, 'discovery': 95}
# EC
# 90
# name
# chinese
# english
# math
# history
# discovery
# EC
# 90
# 80
# 85
# 70
# 95

# %%
# 3年6班 50名學生分數資料 (List of Dictionaries)
student_scores = [
    {"學生姓名": "王小明", "語文": 85, "數學": 92, "英語": 78, "物理": 88, "化學": 90},
    {"學生姓名": "李美芳", "語文": 90, "數學": 88, "英語": 95, "物理": 82, "化學": 85},
    {"學生姓名": "張家豪", "語文": 75, "數學": 80, "英語": 70, "物理": 72, "化學": 78},
    {"學生姓名": "陳建宏", "語文": 82, "數學": 85, "英語": 80, "物理": 85, "化學": 88},
    {"學生姓名": "林雅婷", "語文": 95, "數學": 90, "英語": 92, "物理": 90, "化學": 94},
    {"學生姓名": "黃志強", "語文": 68, "數學": 72, "英語": 65, "物理": 70, "化學": 68},
    {"學生姓名": "吳淑芬", "語文": 88, "數學": 85, "英語": 90, "物理": 86, "化學": 84},
    {"學生姓名": "蔡宗翰", "語文": 72, "數學": 78, "英語": 75, "物理": 74, "化學": 76},
    {"學生姓名": "楊佳玲", "語文": 92, "數學": 95, "英語": 88, "物理": 92, "化學": 90},
    {"學生姓名": "劉冠廷", "語文": 80, "數學": 82, "英語": 85, "物理": 80, "化學": 82},
    {"學生姓名": "郭美玲", "語文": 85, "數學": 84, "英語": 88, "物理": 85, "化學": 86},
    {"學生姓名": "何建國", "語文": 78, "數學": 75, "英語": 72, "物理": 76, "化學": 74},
    {"學生姓名": "趙子龍", "語文": 90, "數學": 92, "英語": 95, "物理": 94, "化學": 92},
    {"學生姓名": "孫小美", "語文": 84, "數學": 86, "英語": 82, "物理": 84, "化學": 86},
    {"學生姓名": "周杰倫", "語文": 70, "數學": 68, "英語": 75, "物理": 72, "化學": 70},
    {"學生姓名": "馬英九", "語文": 95, "數學": 98, "英語": 92, "物理": 96, "化學": 94},
    {"學生姓名": "蔡英文", "語文": 88, "數學": 85, "英語": 90, "物理": 88, "化學": 86},
    {"學生姓名": "韓國瑜", "語文": 72, "數學": 70, "英語": 74, "物理": 72, "化學": 70},
    {"學生姓名": "柯文哲", "語文": 92, "數學": 95, "英語": 90, "物理": 94, "化學": 92},
    {"學生姓名": "賴清德", "語文": 85, "數學": 88, "英語": 82, "物理": 86, "化學": 84},
    {"學生姓名": "朱立倫", "語文": 80, "數學": 78, "英語": 82, "物理": 80, "化學": 78},
    {"學生姓名": "侯友宜", "語文": 75, "數學": 72, "英語": 78, "物理": 75, "化學": 72},
    {"學生姓名": "蘇貞昌", "語文": 82, "數學": 80, "英語": 85, "物理": 82, "化學": 80},
    {"學生姓名": "游錫堃", "語文": 88, "數學": 86, "英語": 90, "物理": 88, "化學": 86},
    {"學生姓名": "陳菊", "語文": 84, "數學": 82, "英語": 86, "物理": 84, "化學": 82},
    {"學生姓名": "謝長廷", "語文": 78, "數學": 76, "英語": 80, "物理": 78, "化學": 76},
    {"學生姓名": "呂秀蓮", "語文": 90, "數學": 88, "英語": 92, "物理": 90, "化學": 88},
    {"學生姓名": "連戰", "語文": 85, "數學": 84, "英語": 88, "物理": 85, "化學": 84},
    {"學生姓名": "宋楚瑜", "語文": 82, "數學": 80, "英語": 85, "物理": 82, "化學": 80},
    {"學生姓名": "王金平", "語文": 80, "數學": 78, "英語": 82, "物理": 80, "化學": 78},
    {"學生姓名": "蕭萬長", "語文": 88, "數學": 86, "英語": 90, "物理": 88, "化學": 86},
    {"學生姓名": "吳敦義", "語文": 84, "數學": 82, "英語": 86, "物理": 84, "化學": 82},
    {"學生姓名": "江啟臣", "語文": 78, "數學": 76, "英語": 80, "物理": 78, "化學": 76},
    {"學生姓名": "蔣萬安", "語文": 92, "數學": 90, "英語": 95, "物理": 92, "化學": 90},
    {"學生姓名": "陳其邁", "語文": 85, "數學": 84, "英語": 88, "物理": 85, "化學": 84},
    {"學生姓名": "黃偉哲", "語文": 82, "數學": 80, "英語": 85, "物理": 82, "化學": 80},
    {"學生姓名": "盧秀燕", "語文": 88, "數學": 86, "英語": 90, "物理": 88, "化學": 86},
    {"學生姓名": "林佳龍", "語文": 84, "數學": 82, "英語": 86, "物理": 84, "化學": 82},
    {"學生姓名": "鄭文燦", "語文": 80, "數學": 78, "英語": 82, "物理": 80, "化學": 78},
    {"學生姓名": "潘孟安", "語文": 82, "數學": 80, "英語": 85, "物理": 82, "化學": 80},
    {"學生姓名": "林右昌", "語文": 85, "數學": 84, "英語": 88, "物理": 85, "化學": 84},
    {"學生姓名": "林智堅", "語文": 88, "數學": 86, "英語": 90, "物理": 88, "化學": 86},
    {"學生姓名": "徐耀昌", "語文": 72, "數學": 74, "英語": 70, "物理": 72, "化學": 74},
    {"學生姓名": "王惠美", "語文": 84, "數學": 82, "英語": 86, "物理": 84, "化學": 82},
    {"學生姓名": "張麗善", "語文": 78, "數學": 76, "英語": 80, "物理": 78, "化學": 76},
    {"學生姓名": "黃敏惠", "語文": 90, "數學": 88, "英語": 92, "物理": 90, "化學": 88},
    {"學生姓名": "項冠宏", "語文": 80, "數學": 82, "英語": 78, "物理": 80, "化學": 82},
    {"學生姓名": "祝雅琪", "語文": 88, "數學": 86, "英語": 90, "物理": 88, "化學": 86},
    {"學生姓名": "董志強", "語文": 72, "數學": 74, "英語": 70, "物理": 72, "化學": 74},
    {"學生姓名": "梁美惠", "語文": 95, "數學": 92, "英語": 98, "物理": 95, "化學": 92},
    {"學生姓名": "范家榮", "語文": 84, "數學": 86, "英語": 82, "物理": 84, "化學": 86}
]

# Print第一位學生的資料
for student in student_scores:
	print(student)
	
print(student_scores[0]["學生姓名"], student_scores[0]["語文"])  # print第一位學生的語文成績
print(student_scores[0]) # print第一位學生的所有資料
# Out:
# {'學生姓名': '王小明', '語文': 85, '數學': 92, '英語': 78, '物理': 88, '化學': 90}
# {'學生姓名': '李美芳', '語文': 90, '數學': 88, '英語': 95, '物理': 82, '化學': 85}
# {'學生姓名': '張家豪', '語文': 75, '數學': 80, '英語': 70, '物理': 72, '化學': 78}
# {'學生姓名': '陳建宏', '語文': 82, '數學': 85, '英語': 80, '物理': 85, '化學': 88}
# {'學生姓名': '林雅婷', '語文': 95, '數學': 90, '英語': 92, '物理': 90, '化學': 94}
# {'學生姓名': '黃志強', '語文': 68, '數學': 72, '英語': 65, '物理': 70, '化學': 68}
# {'學生姓名': '吳淑芬', '語文': 88, '數學': 85, '英語': 90, '物理': 86, '化學': 84}
# {'學生姓名': '蔡宗翰', '語文': 72, '數學': 78, '英語': 75, '物理': 74, '化學': 76}
# {'學生姓名': '楊佳玲', '語文': 92, '數學': 95, '英語': 88, '物理': 92, '化學': 90}
# {'學生姓名': '劉冠廷', '語文': 80, '數學': 82, '英語': 85, '物理': 80, '化學': 82}
# {'學生姓名': '郭美玲', '語文': 85, '數學': 84, '英語': 88, '物理': 85, '化學': 86}
# {'學生姓名': '何建國', '語文': 78, '數學': 75, '英語': 72, '物理': 76, '化學': 74}
# {'學生姓名': '趙子龍', '語文': 90, '數學': 92, '英語': 95, '物理': 94, '化學': 92}
# {'學生姓名': '孫小美', '語文': 84, '數學': 86, '英語': 82, '物理': 84, '化學': 86}
# {'學生姓名': '周杰倫', '語文': 70, '數學': 68, '英語': 75, '物理': 72, '化學': 70}
# {'學生姓名': '馬英九', '語文': 95, '數學': 98, '英語': 92, '物理': 96, '化學': 94}
# {'學生姓名': '蔡英文', '語文': 88, '數學': 85, '英語': 90, '物理': 88, '化學': 86}
# {'學生姓名': '韓國瑜', '語文': 72, '數學': 70, '英語': 74, '物理': 72, '化學': 70}
# {'學生姓名': '柯文哲', '語文': 92, '數學': 95, '英語': 90, '物理': 94, '化學': 92}
# {'學生姓名': '賴清德', '語文': 85, '數學': 88, '英語': 82, '物理': 86, '化學': 84}
# {'學生姓名': '朱立倫', '語文': 80, '數學': 78, '英語': 82, '物理': 80, '化學': 78}
# {'學生姓名': '侯友宜', '語文': 75, '數學': 72, '英語': 78, '物理': 75, '化學': 72}
# {'學生姓名': '蘇貞昌', '語文': 82, '數學': 80, '英語': 85, '物理': 82, '化學': 80}
# {'學生姓名': '游錫堃', '語文': 88, '數學': 86, '英語': 90, '物理': 88, '化學': 86}
# {'學生姓名': '陳菊', '語文': 84, '數學': 82, '英語': 86, '物理': 84, '化學': 82}
# {'學生姓名': '謝長廷', '語文': 78, '數學': 76, '英語': 80, '物理': 78, '化學': 76}
# {'學生姓名': '呂秀蓮', '語文': 90, '數學': 88, '英語': 92, '物理': 90, '化學': 88}
# {'學生姓名': '連戰', '語文': 85, '數學': 84, '英語': 88, '物理': 85, '化學': 84}
# {'學生姓名': '宋楚瑜', '語文': 82, '數學': 80, '英語': 85, '物理': 82, '化學': 80}
# {'學生姓名': '王金平', '語文': 80, '數學': 78, '英語': 82, '物理': 80, '化學': 78}
# {'學生姓名': '蕭萬長', '語文': 88, '數學': 86, '英語': 90, '物理': 88, '化學': 86}
# {'學生姓名': '吳敦義', '語文': 84, '數學': 82, '英語': 86, '物理': 84, '化學': 82}
# {'學生姓名': '江啟臣', '語文': 78, '數學': 76, '英語': 80, '物理': 78, '化學': 76}
# {'學生姓名': '蔣萬安', '語文': 92, '數學': 90, '英語': 95, '物理': 92, '化學': 90}
# {'學生姓名': '陳其邁', '語文': 85, '數學': 84, '英語': 88, '物理': 85, '化學': 84}
# {'學生姓名': '黃偉哲', '語文': 82, '數學': 80, '英語': 85, '物理': 82, '化學': 80}
# {'學生姓名': '盧秀燕', '語文': 88, '數學': 86, '英語': 90, '物理': 88, '化學': 86}
# {'學生姓名': '林佳龍', '語文': 84, '數學': 82, '英語': 86, '物理': 84, '化學': 82}
# {'學生姓名': '鄭文燦', '語文': 80, '數學': 78, '英語': 82, '物理': 80, '化學': 78}
# {'學生姓名': '潘孟安', '語文': 82, '數學': 80, '英語': 85, '物理': 82, '化學': 80}
# {'學生姓名': '林右昌', '語文': 85, '數學': 84, '英語': 88, '物理': 85, '化學': 84}
# {'學生姓名': '林智堅', '語文': 88, '數學': 86, '英語': 90, '物理': 88, '化學': 86}
# {'學生姓名': '徐耀昌', '語文': 72, '數學': 74, '英語': 70, '物理': 72, '化學': 74}
# {'學生姓名': '王惠美', '語文': 84, '數學': 82, '英語': 86, '物理': 84, '化學': 82}
# {'學生姓名': '張麗善', '語文': 78, '數學': 76, '英語': 80, '物理': 78, '化學': 76}
# {'學生姓名': '黃敏惠', '語文': 90, '數學': 88, '英語': 92, '物理': 90, '化學': 88}
# {'學生姓名': '項冠宏', '語文': 80, '數學': 82, '英語': 78, '物理': 80, '化學': 82}
# {'學生姓名': '祝雅琪', '語文': 88, '數學': 86, '英語': 90, '物理': 88, '化學': 86}
# {'學生姓名': '董志強', '語文': 72, '數學': 74, '英語': 70, '物理': 72, '化學': 74}
# {'學生姓名': '梁美惠', '語文': 95, '數學': 92, '英語': 98, '物理': 95, '化學': 92}
# {'學生姓名': '范家榮', '語文': 84, '數學': 86, '英語': 82, '物理': 84, '化學': 86}
# 王小明 85
# {'學生姓名': '王小明', '語文': 85, '數學': 92, '英語': 78, '物理': 88, '化學': 90}

# %%
# 計算每位學生總分與平均
ranked_students = []

for student in student_scores:
    total = student["語文"] + student["數學"] + student["英語"] + student["物理"] + student["化學"]
    average = total / 5
    ranked_students.append({
        "學生姓名": student["學生姓名"],
        "總分": total,
        "平均": average
    })

print("=== 所有學生總分與平均 ===")
for s in ranked_students:
    print(f"{s['學生姓名']}: 總分={s['總分']}, 平均={s['平均']:.2f}")

top3 = sorted(ranked_students, key=lambda x: x["總分"], reverse=True)[:3]

print("\n=== 前 3 名 ===")
for i, s in enumerate(top3, start=1):
    print(f"第{i}名 {s['學生姓名']}: 總分={s['總分']}, 平均={s['平均']:.2f}")
# Out:
# === 所有學生總分與平均 ===
# 王小明: 總分=433, 平均=86.60
# 李美芳: 總分=440, 平均=88.00
# 張家豪: 總分=375, 平均=75.00
# 陳建宏: 總分=420, 平均=84.00
# 林雅婷: 總分=461, 平均=92.20
# 黃志強: 總分=343, 平均=68.60
# 吳淑芬: 總分=433, 平均=86.60
# 蔡宗翰: 總分=375, 平均=75.00
# 楊佳玲: 總分=457, 平均=91.40
# 劉冠廷: 總分=409, 平均=81.80
# 郭美玲: 總分=428, 平均=85.60
# 何建國: 總分=375, 平均=75.00
# 趙子龍: 總分=463, 平均=92.60
# 孫小美: 總分=422, 平均=84.40
# 周杰倫: 總分=355, 平均=71.00
# 馬英九: 總分=475, 平均=95.00
# 蔡英文: 總分=437, 平均=87.40
# 韓國瑜: 總分=358, 平均=71.60
# 柯文哲: 總分=463, 平均=92.60
# 賴清德: 總分=425, 平均=85.00
# 朱立倫: 總分=398, 平均=79.60
# 侯友宜: 總分=372, 平均=74.40
# 蘇貞昌: 總分=409, 平均=81.80
# 游錫堃: 總分=438, 平均=87.60
# 陳菊: 總分=418, 平均=83.60
# 謝長廷: 總分=388, 平均=77.60
# 呂秀蓮: 總分=448, 平均=89.60
# 連戰: 總分=426, 平均=85.20
# 宋楚瑜: 總分=409, 平均=81.80
# 王金平: 總分=398, 平均=79.60
# 蕭萬長: 總分=438, 平均=87.60
# 吳敦義: 總分=418, 平均=83.60
# 江啟臣: 總分=388, 平均=77.60
# 蔣萬安: 總分=459, 平均=91.80
# 陳其邁: 總分=426, 平均=85.20
# 黃偉哲: 總分=409, 平均=81.80
# 盧秀燕: 總分=438, 平均=87.60
# 林佳龍: 總分=418, 平均=83.60
# 鄭文燦: 總分=398, 平均=79.60
# 潘孟安: 總分=409, 平均=81.80
# 林右昌: 總分=426, 平均=85.20
# 林智堅: 總分=438, 平均=87.60
# 徐耀昌: 總分=362, 平均=72.40
# 王惠美: 總分=418, 平均=83.60
# 張麗善: 總分=388, 平均=77.60
# 黃敏惠: 總分=448, 平均=89.60
# 項冠宏: 總分=402, 平均=80.40
# 祝雅琪: 總分=438, 平均=87.60
# 董志強: 總分=362, 平均=72.40
# 梁美惠: 總分=472, 平均=94.40
# 范家榮: 總分=422, 平均=84.40
#
# === 前 3 名 ===
# 第1名 馬英九: 總分=475, 平均=95.00
# 第2名 梁美惠: 總分=472, 平均=94.40
# 第3名 趙子龍: 總分=463, 平均=92.60

# %%
# open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)
# 讀取txt檔
# file是實體的物件, 裡面有實體屬性如name, mode, closed, encoding等, 還有實體方法如read(), readline(), readlines(), close()等, 可以使用這些屬性和方法來操作檔案
file = open("student.txt","r",encoding="utf-8")
print(file.name)
print(file.mode)
print(file.closed)
print(file.encoding)
print(file.read())
file.close()
print(file.closed)
# Out:
# student.txt
# r
# False
# utf-8
# 王小明
# 陳大華
# 林美玲
# True

# %%
#open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)

#引數值的呼叫
try:
	with open("student.txt", "r", -1, "utf-8") as file: #讀取模式"r"代表read,encoding="utf-8"代表使用UTF-8編碼讀取檔案
			data = file.read() #read()方法會讀取整個檔案的內容,就不用再寫file.close()來關閉檔案,因為with語句會自動幫我們關閉檔案
			print(data)
except Exception as e:
	print("發生錯誤:", e) #如果發生錯誤,印出錯誤訊息
	
#引述名稱的呼叫
try:
	with open(file="student.txt", mode="r", encoding="utf-8") as file: 
			data = file.read()
			print(data)
except Exception as e:
	print("發生錯誤:", e)   

#混合的呼叫
try:
	with open("student.txt", "r", encoding="utf-8") as file: 
			data = file.read()
			print(data)
except Exception as e:
	print("發生錯誤:", e)
# Out:
# 王小明
# 陳大華
# 林美玲
# 王小明
# 陳大華
# 林美玲
# 王小明
# 陳大華
# 林美玲

# %%
#讀取csv檔案
import csv

#方法一: 使用csv模組的reader()方法
with open("考試分數_3年6班.csv", "r", encoding="utf-8") as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)

#方法二: 使用csv模組的DictReader()方法,這樣每一行會被讀取成一個字典,字典的key是csv檔案的第一行(欄位名稱),value是每一行對應的資料 <較優>
with open("考試分數_3年6班.csv", "r", encoding="utf-8") as file:
    reader = csv.DictReader(file)
    for row in reader:
        print(row)
# Out:
# ['學生姓名', '語文', '數學', '英語', '物理', '化學']
# ['王小明', '85', '92', '78', '88', '90']
# ['李美芳', '90', '88', '95', '82', '85']
# ['張家豪', '75', '80', '70', '72', '78']
# ['陳建宏', '82', '85', '80', '85', '88']
# ['林志強', '68', '72', '65', '70', '60']
# ['黃淑惠', '92', '95', '90', '94', '92']
# ['吳明憲', '80', '78', '85', '80', '82']
# ['蔡佩珊', '88', '90', '92', '88', '90']
# ['郭政達', '72', '75', '68', '70', '72']
# ['楊佳琪', '95', '92', '98', '95', '96']
# ['趙冠宇', '85', '82', '88', '84', '86']
# ['許家榮', '78', '80', '75', '78', '80']
# ['鄭雅文', '90', '92', '88', '90', '92']
# ['謝承翰', '82', '84', '80', '82', '84']
# ['洪婉婷', '88', '86', '90', '88', '86']
# ['曾志翔', '70', '72', '68', '70', '72']
# ['劉美玲', '92', '94', '90', '92', '94']
# ['蘇俊宏', '85', '80', '82', '85', '80']
# ['葉雅婷', '94', '96', '92', '94', '96']
# ['莊凱翔', '76', '78', '74', '76', '78']
# ['呂佩穎', '88', '90', '86', '88', '90']
# ['何志龍', '82', '80', '84', '82', '80']
# ['羅佳穎', '90', '88', '92', '90', '88']
# ['高家豪', '74', '76', '72', '74', '76']
# ['蕭淑芬', '92', '90', '94', '92', '90']
# ['潘冠宏', '80', '82', '78', '80', '82']
# ['田雅琪', '88', '86', '90', '88', '86']
# ['馮志強', '72', '74', '70', '72', '74']
# ['蔣美惠', '95', '92', '98', '95', '92']
# ['曹家榮', '84', '86', '82', '84', '86']
# ['魏佩珊', '90', '92', '88', '90', '92']
# ['彭承翰', '78', '80', '76', '78', '80']
# ['袁佳琪', '92', '94', '90', '92', '94']
# ['盧志宏', '82', '84', '80', '82', '84']
# ['鄧婉婷', '88', '86', '90', '88', '86']
# ['范家豪', '70', '72', '68', '70', '72']
# ['汪美玲', '94', '96', '92', '94', '96']
# ['賈俊宏', '86', '84', '88', '86', '84']
# ['陸雅婷', '90', '92', '88', '90', '92']
# ['韓凱翔', '74', '76', '72', '74', '76']
# ['尤佩穎', '88', '90', '86', '88', '90']
# ['柏志龍', '82', '80', '84', '82', '80']
# ['焦佳穎', '92', '90', '94', '92', '90']
# ['舒家豪', '76', '78', '74', '76', '78']
# ['屈淑芬', '90', '88', '92', '90', '88']
# ['項冠宏', '80', '82', '78', '80', '82']
# ['祝雅琪', '88', '86', '90', '88', '86']
# ['董志強', '72', '74', '70', '72', '74']
# ['梁美惠', '95', '92', '98', '95', '92']
# ['范家榮', '84', '86', '82', '84', '86']
# {'學生姓名': '王小明', '語文': '85', '數學': '92', '英語': '78', '物理': '88', '化學': '90'}
# {'學生姓名': '李美芳', '語文': '90', '數學': '88', '英語': '95', '物理': '82', '化學': '85'}
# {'學生姓名': '張家豪', '語文': '75', '數學': '80', '英語': '70', '物理': '72', '化學': '78'}
# {'學生姓名': '陳建宏', '語文': '82', '數學': '85', '英語': '80', '物理': '85', '化學': '88'}
# {'學生姓名': '林志強', '語文': '68', '數學': '72', '英語': '65', '物理': '70', '化學': '60'}
# {'學生姓名': '黃淑惠', '語文': '92', '數學': '95', '英語': '90', '物理': '94', '化學': '92'}
# {'學生姓名': '吳明憲', '語文': '80', '數學': '78', '英語': '85', '物理': '80', '化學': '82'}
# {'學生姓名': '蔡佩珊', '語文': '88', '數學': '90', '英語': '92', '物理': '88', '化學': '90'}
# {'學生姓名': '郭政達', '語文': '72', '數學': '75', '英語': '68', '物理': '70', '化學': '72'}
# {'學生姓名': '楊佳琪', '語文': '95', '數學': '92', '英語': '98', '物理': '95', '化學': '96'}
# {'學生姓名': '趙冠宇', '語文': '85', '數學': '82', '英語': '88', '物理': '84', '化學': '86'}
# {'學生姓名': '許家榮', '語文': '78', '數學': '80', '英語': '75', '物理': '78', '化學': '80'}
# {'學生姓名': '鄭雅文', '語文': '90', '數學': '92', '英語': '88', '物理': '90', '化學': '92'}
# {'學生姓名': '謝承翰', '語文': '82', '數學': '84', '英語': '80', '物理': '82', '化學': '84'}
# {'學生姓名': '洪婉婷', '語文': '88', '數學': '86', '英語': '90', '物理': '88', '化學': '86'}
# {'學生姓名': '曾志翔', '語文': '70', '數學': '72', '英語': '68', '物理': '70', '化學': '72'}
# {'學生姓名': '劉美玲', '語文': '92', '數學': '94', '英語': '90', '物理': '92', '化學': '94'}
# {'學生姓名': '蘇俊宏', '語文': '85', '數學': '80', '英語': '82', '物理': '85', '化學': '80'}
# {'學生姓名': '葉雅婷', '語文': '94', '數學': '96', '英語': '92', '物理': '94', '化學': '96'}
# {'學生姓名': '莊凱翔', '語文': '76', '數學': '78', '英語': '74', '物理': '76', '化學': '78'}
# {'學生姓名': '呂佩穎', '語文': '88', '數學': '90', '英語': '86', '物理': '88', '化學': '90'}
# {'學生姓名': '何志龍', '語文': '82', '數學': '80', '英語': '84', '物理': '82', '化學': '80'}
# {'學生姓名': '羅佳穎', '語文': '90', '數學': '88', '英語': '92', '物理': '90', '化學': '88'}
# {'學生姓名': '高家豪', '語文': '74', '數學': '76', '英語': '72', '物理': '74', '化學': '76'}
# {'學生姓名': '蕭淑芬', '語文': '92', '數學': '90', '英語': '94', '物理': '92', '化學': '90'}
# {'學生姓名': '潘冠宏', '語文': '80', '數學': '82', '英語': '78', '物理': '80', '化學': '82'}
# {'學生姓名': '田雅琪', '語文': '88', '數學': '86', '英語': '90', '物理': '88', '化學': '86'}
# {'學生姓名': '馮志強', '語文': '72', '數學': '74', '英語': '70', '物理': '72', '化學': '74'}
# {'學生姓名': '蔣美惠', '語文': '95', '數學': '92', '英語': '98', '物理': '95', '化學': '92'}
# {'學生姓名': '曹家榮', '語文': '84', '數學': '86', '英語': '82', '物理': '84', '化學': '86'}
# {'學生姓名': '魏佩珊', '語文': '90', '數學': '92', '英語': '88', '物理': '90', '化學': '92'}
# {'學生姓名': '彭承翰', '語文': '78', '數學': '80', '英語': '76', '物理': '78', '化學': '80'}
# {'學生姓名': '袁佳琪', '語文': '92', '數學': '94', '英語': '90', '物理': '92', '化學': '94'}
# {'學生姓名': '盧志宏', '語文': '82', '數學': '84', '英語': '80', '物理': '82', '化學': '84'}
# {'學生姓名': '鄧婉婷', '語文': '88', '數學': '86', '英語': '90', '物理': '88', '化學': '86'}
# {'學生姓名': '范家豪', '語文': '70', '數學': '72', '英語': '68', '物理': '70', '化學': '72'}
# {'學生姓名': '汪美玲', '語文': '94', '數學': '96', '英語': '92', '物理': '94', '化學': '96'}
# {'學生姓名': '賈俊宏', '語文': '86', '數學': '84', '英語': '88', '物理': '86', '化學': '84'}
# {'學生姓名': '陸雅婷', '語文': '90', '數學': '92', '英語': '88', '物理': '90', '化學': '92'}
# {'學生姓名': '韓凱翔', '語文': '74', '數學': '76', '英語': '72', '物理': '74', '化學': '76'}
# {'學生姓名': '尤佩穎', '語文': '88', '數學': '90', '英語': '86', '物理': '88', '化學': '90'}
# {'學生姓名': '柏志龍', '語文': '82', '數學': '80', '英語': '84', '物理': '82', '化學': '80'}
# {'學生姓名': '焦佳穎', '語文': '92', '數學': '90', '英語': '94', '物理': '92', '化學': '90'}
# {'學生姓名': '舒家豪', '語文': '76', '數學': '78', '英語': '74', '物理': '76', '化學': '78'}
# {'學生姓名': '屈淑芬', '語文': '90', '數學': '88', '英語': '92', '物理': '90', '化學': '88'}
# {'學生姓名': '項冠宏', '語文': '80', '數學': '82', '英語': '78', '物理': '80', '化學': '82'}
# {'學生姓名': '祝雅琪', '語文': '88', '數學': '86', '英語': '90', '物理': '88', '化學': '86'}
# {'學生姓名': '董志強', '語文': '72', '數學': '74', '英語': '70', '物理': '72', '化學': '74'}
# {'學生姓名': '梁美惠', '語文': '95', '數學': '92', '英語': '98', '物理': '95', '化學': '92'}
# {'學生姓名': '范家榮', '語文': '84', '數學': '86', '英語': '82', '物理': '84', '化學': '86'}
