# %%
#建立工廠
class Person:
    pass

# %%
p1 = Person()
type(p1)
# Out:
# __main__.Person

# %%
#建立工廠
class Person:
    def __init__(self, id):
        #建立一個attribute
        self.name = id

# %%
p2 = Person("robert")
p2.name
# Out:
# 'robert'

# %%
p3 = Person("jenny")
p3.name
# Out:
# 'jenny'
